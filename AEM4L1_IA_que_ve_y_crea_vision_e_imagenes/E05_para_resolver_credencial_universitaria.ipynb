# %% [markdown]
# # AEM4L1 E05 — Credencial universitaria
#
# **Objetivo:** Resolver una variación imagen → JSON → Pydantic.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Extraer student_name, student_id, institution, career y expiration_date.

# %%
from pydantic import BaseModel
from datetime import date

# TODO: Definir modelo StudentCredential
# class StudentCredential(BaseModel):
#     student_name: str
#     student_id: str
#     institution: str
#     career: str
#     expiration_date: date

llm_output = {
    # TODO: completar salida simulada del modelo
}

# TODO: validar con Pydantic
