# %% [markdown]
# # AEM4L1 E01 — Ticket de supermercado → texto
#
# **Objetivo:** Extraer texto libre desde una imagen simulada.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Simulamos una extracción multimodal. En clase podés reemplazar el mock por una llamada real a GPT-4o Vision/Gemini.

# %%
def parse_image_to_text(image_path: str) -> str:
    return '''
    Supermercado Norte
    Fecha: 12/06/2026
    Producto: Pan lactal $2500
    Producto: Leche $1800
    Producto: Yerba $4200
    Total: $8500
    Pago: Tarjeta
    '''

text = parse_image_to_text("ticket_supermercado.png")
print(text)
