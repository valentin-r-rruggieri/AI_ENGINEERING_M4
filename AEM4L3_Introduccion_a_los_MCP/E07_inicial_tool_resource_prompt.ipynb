# %% [markdown]
# # AEM4L3 E07 — Inicial | Tool, Resource o Prompt
#
# **Objetivo:** Refuerzo básico de clasificación.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Tres ejemplos simples.

# %%
examples = [
    ("Documento con política de cambios", "Resource"),
    ("Crear reclamo", "Tool"),
    ("Responder con tono formal", "Prompt")
]

for text, answer in examples:
    print(f"{text} → {answer}")
