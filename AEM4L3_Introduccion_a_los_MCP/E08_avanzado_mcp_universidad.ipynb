# %% [markdown]
# # AEM4L3 E08 — Avanzado | MCP universidad
#
# **Objetivo:** Diseñar arquitectura MCP completa.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Incluye tools, resources, prompts, scopes y auditoría.

# %%
import json

mcp_university = {
    "transport": "HTTP streaming",
    "resources": ["reglamento.md", "calendario_examenes.json", "programa_carrera.md"],
    "prompts": ["respuesta_academica", "resumen_estado_alumno"],
    "tools": [
        {"name": "crear_ticket_alumno", "scope": "tickets:write"},
        {"name": "solicitar_certificado", "scope": "certificates:write"},
        {"name": "reservar_turno_secretaria", "scope": "appointments:write"}
    ],
    "audit_logs": ["request_id", "tool_name", "tenant_id", "status", "latency_ms"]
}

print(json.dumps(mcp_university, indent=2, ensure_ascii=False))
