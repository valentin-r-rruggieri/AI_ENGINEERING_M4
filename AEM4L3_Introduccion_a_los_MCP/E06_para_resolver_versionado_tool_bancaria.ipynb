# %% [markdown]
# # AEM4L3 E06 — Versionado tool bancaria
#
# **Objetivo:** Clasificar cambios de schema.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Decidir si cada cambio es aditivo o rompiente.

# %%
schema_v1 = {"account_id": "string", "amount": "number"}
changes = [
    "Agregar description opcional",
    "Cambiar amount a string",
    "Agregar currency obligatorio",
    "Agregar operation_id opcional",
    "Eliminar account_id"
]

# TODO: clasificar cada cambio
for change in changes:
    print(change, "→ TODO")
