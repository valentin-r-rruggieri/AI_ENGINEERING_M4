# %% [markdown]
# # AEM4L3 E03 — Versionado de schema
#
# **Objetivo:** Clasificar cambios aditivos y rompientes.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Agregar opcionales suele ser seguro; renombrar, quitar o cambiar tipos rompe compatibilidad.

# %%
changes = {
    "Agregar customer_email opcional": "Aditivo",
    "Renombrar order_id a orderNumber": "Rompiente",
    "Agregar refund_type obligatorio": "Rompiente",
    "Agregar priority opcional": "Aditivo"
}

for change, kind in changes.items():
    print(f"{change:45} → {kind}")
