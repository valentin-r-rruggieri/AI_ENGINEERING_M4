# %% [markdown]
# # AEM4L3 E05 — MCP para RRHH
#
# **Objetivo:** Diseñar tools, resources, prompts, schemas y scopes.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Variación de MCP aplicada a RRHH.

# %%
# TODO: completar diseño MCP para RRHH
mcp_design = {
    "tools": [
        # request_vacation, create_hr_ticket, update_employee_address
    ],
    "resources": [
        # vacation_policy.md, employee_profile.json
    ],
    "prompts": [
        # hr_response_template
    ]
}

mcp_design
