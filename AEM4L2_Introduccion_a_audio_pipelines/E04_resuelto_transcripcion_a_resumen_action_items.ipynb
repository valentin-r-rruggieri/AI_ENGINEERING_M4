# %% [markdown]
# # AEM4L2 E04 — Transcripción → resumen y action items
#
# **Objetivo:** Transformar transcript en información accionable.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Simula un post-procesamiento posterior al ASR.

# %%
transcript = "Hola, llamo porque el pedido 4521 no llegó. Lo necesitaba para hoy. Quiero saber si pueden enviarlo urgente o cancelar la compra."

output = {
    "summary": "El cliente reclama que el pedido 4521 no llegó y solicita envío urgente o cancelación.",
    "intent": "reclamo_entrega",
    "urgency": "high",
    "action_items": [
        "Verificar estado del pedido 4521",
        "Ofrecer reenvío urgente o cancelación"
    ]
}

output
