# %% [markdown]
# # AEM4L2 E05 — Reclamo bancario
#
# **Objetivo:** Generar summary, intent, urgency y action_items.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Resolver una variación bancaria del ejercicio de resumen.

# %%
transcript = "Hola, hice una transferencia ayer y todavía no se acreditó. Necesito saber si quedó retenida o si hubo algún error."

# TODO: completar output estructurado
output = {
    "summary": "",
    "intent": "",
    "urgency": "",
    "action_items": []
}
output
