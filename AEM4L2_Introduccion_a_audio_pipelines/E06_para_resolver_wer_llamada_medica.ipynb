# %% [markdown]
# # AEM4L2 E06 — WER de llamada médica
#
# **Objetivo:** Calcular WER y riesgo del error.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Caso médico: un error puede cambiar la indicación clínica.

# %%
reference = "El paciente debe tomar la medicación cada ocho horas"
hypothesis = "El paciente debe tomar medicación cada dos horas"

# TODO: calcular S, D, I, N y WER
# TODO: explicar por qué este error es riesgoso
