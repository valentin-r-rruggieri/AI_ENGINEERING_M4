# %% [markdown]
# # AEM4L2 E01 — Referencia humana vs ASR
#
# **Objetivo:** Comparar ground truth contra hipótesis ASR.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Se detecta un error de sustitución.

# %%
reference = "Hola, quiero cambiar la dirección de entrega de mi pedido."
hypothesis = "Hola, quiero cambiar la dirección de entrega de mi perdido."

print("Referencia:", reference)
print("Hipótesis:", hypothesis)
print("Error principal: pedido → perdido = substitution")
