# %% [markdown]
# # AEM4L5 E08 — Avanzado | Production Architecture Plan
#
# **Objetivo:** Diseñar un plan de producción.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Servicio de resumen legal con bajo presupuesto, tráfico impredecible y personalización por cliente.

# %%
production_plan = {
    "adaptacion": "TODO: LoRA o full fine-tuning",
    "serving": "TODO: serverless, servidor o híbrido",
    "profiling": ["latency_ms", "cumtime", "tottime"],
    "async_strategy": "TODO: dónde aplicar async",
    "metrics": ["p50_latency", "p95_latency", "cost_per_request", "error_rate"],
    "risks": []
}

production_plan
