# %% [markdown]
# # AEM4L5 E07 — Inicial | CPU-bound o I/O-bound
#
# **Objetivo:** Clasificar tareas.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Elegir la estrategia correcta depende del tipo de cuello de botella.

# %%
tasks = {
    "Limpiar 1 millón de strings": "CPU-bound",
    "Esperar respuesta de API": "I/O-bound",
    "Descargar PDF de S3": "I/O-bound",
    "Calcular embeddings localmente": "CPU/GPU-bound",
    "Guardar resultado en DB": "I/O-bound"
}

for task, kind in tasks.items():
    print(f"{task:35} → {kind}")
