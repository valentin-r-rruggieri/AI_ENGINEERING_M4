# %% [markdown]
# # AEM4L5 E05 — Arquitectura para resúmenes
#
# **Objetivo:** Elegir patrón de despliegue.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Casos: bajo tráfico, alta concurrencia, uso interno y SaaS.

# %%
# TODO: completar decisiones
cases = [
    "Resúmenes legales con 30 requests por día",
    "Chatbot de soporte con 500 usuarios simultáneos",
    "API interna usada solo de lunes a viernes",
    "Servicio SaaS con picos impredecibles"
]

architecture_decisions = []
architecture_decisions
