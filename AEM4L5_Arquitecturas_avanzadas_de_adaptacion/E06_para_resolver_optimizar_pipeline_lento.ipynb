# %% [markdown]
# # AEM4L5 E06 — Optimizar pipeline lento
#
# **Objetivo:** Perfilar, detectar hotspot y refactorizar.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Ejercicio basado en cProfile.

# %%
def normalize(texts):
    result = []
    for text in texts:
        clean = ""
        for c in text:
            if c.isalnum() or c.isspace():
                clean += c.lower()
        result.append(clean)
    return result

texts = ["Texto de prueba!!! con símbolos ###"] * 10000

# TODO: perfilar normalize(texts)
# TODO: refactorizar usando regex
# TODO: comparar tiempos
