# %% [markdown]
# # AEM4L5 E01 — Full fine-tuning vs LoRA
#
# **Objetivo:** Comparar storage, costo y flexibilidad.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# LoRA permite 1 base + N adapters.

# %%
strategies = [
    {"strategy": "Full fine-tuning", "storage": "5 modelos completos", "cost": "alto", "flexibility": "baja"},
    {"strategy": "LoRA", "storage": "1 modelo base + 5 adapters", "cost": "bajo", "flexibility": "alta"},
]

for s in strategies:
    print(s)
