# %% [markdown]
# # E03 - De RNN a Transformer sin misterio
#
# **Tema:** Procesamiento secuencial versus procesamiento paralelo
#
# **Objetivo docente:** Entender por contraste por que Transformer fue disruptivo frente a RNN/LSTM.
#
# **Como usarlo en clase:** este notebook funciona como una mini estacion teorica. Primero se leen las definiciones, despues se mira el grafico, luego se ejecuta la celda Python y finalmente se trabajan las tres actividades. La celda de codigo es apoyo visual, no el centro de la clase.

# %% [markdown]
# ## Imagen guia del tema <!-- data-aem4-visual-assets -->
#
# ![e03 rnn vs transformer](assets/visuals/e03_rnn_vs_transformer.svg)
#
# Usa esta imagen como punto de partida antes de ejecutar las celdas. La idea es que el alumno vea el flujo completo antes de mirar numeros.

# %% [markdown]
# ## 1. Definiciones base
#
# Antes de programar o discutir herramientas, fijamos vocabulario. El objetivo es que el alumno pueda explicar cada palabra tecnica con una frase simple.
#
# | Concepto | Definicion simple |
# |---|---|
# | **RNN** | Red que procesa secuencias paso a paso. |
# | **LSTM** | RNN con memoria mejorada para informacion relevante. |
# | **Transformer** | Arquitectura que procesa posiciones en paralelo con attention. |
# | **Dependencia larga** | Relacion entre partes alejadas de un texto. |
# | **Paralelizacion** | Procesar muchas posiciones al mismo tiempo. |

# %% [markdown]
# ## 2. Mapa visual del tema
#
# Este grafico se usa para narrar el recorrido del concepto en voz alta: que entra, que se transforma y que decision aparece.
#
# ```mermaid
# flowchart TB
#     X["Texto completo"] --> R["RNN/LSTM: paso a paso"]
#     X --> T["Transformer: posiciones en paralelo"]
#     R --> P["Puede perder senales lejanas"]
#     T --> C["Conecta contexto de forma directa"]
# ```

# %% [markdown]
# ## 3. Tres ejemplos guiados
#
# Cada tema se baja a tres casos cortos. La pregunta docente es: que cambia, que restriccion aparece y que decision tecnica se desprende.
#
# | Ejemplo | Que muestra |
# |---|---|
# | **Oracion deportiva** | Conectar lesion, delantero y gol aunque no esten pegados. |
# | **Contrato legal** | Una condicion inicial puede afectar una obligacion final. |
# | **Codigo** | Una variable definida antes puede importar muchas lineas despues. |

# %%
for n in [5, 20, 80]:
    print(f"{n:>3} tokens -> RNN: {n} pasos secuenciales | Transformer: posiciones en paralelo")

# %% [markdown]
# ## 4. Como interpretar la celda Python
#
# La salida no intenta implementar un modelo real. Sirve para volver visible una idea: cantidad de tokens, relaciones, memoria, adaptacion o trade-off.
#
# Preguntas rapidas:
#
# - Que valor o etiqueta cambio mas?
# - Que parte del grafico aparece reflejada en la salida?
# - Que decision tomariamos si esto fuera un sistema real?

# %% [markdown]
# ## 5. Actividades practicas minimas
#
# Hay minimo tres actividades por tema para que la clase no quede en definiciones sueltas.
#
# 1. **Elegir arquitectura.** Clasificar frases cortas, resumir contratos y completar codigo.
# 2. **Buscar dependencia.** Marcar palabras que deben conectarse aunque esten lejos.
# 3. **Explicar paralelismo.** Decir por que GPU y Transformer combinan bien.

# %% [markdown]
# ## 6. Errores comunes y correccion docente
#
# | Error comun | Correccion docente |
# |---|---|
# | **RNN no sirve nunca** | Puede servir en casos pequenos o especificos. |
# | **Transformer no cuesta** | Tiene costo fuerte con muchos tokens. |
# | **Paralelo es instantaneo** | Mejora escalabilidad, pero no elimina limites. |

# %% [markdown]
# ## 7. Cierre del notebook
#
# Idea para repetir al cerrar:
#
# > En este tema no buscamos memorizar nombres; buscamos justificar una decision tecnica con ejemplos simples.
#
# **Puente al siguiente tema:** El motor conceptual del Transformer es self-attention.
