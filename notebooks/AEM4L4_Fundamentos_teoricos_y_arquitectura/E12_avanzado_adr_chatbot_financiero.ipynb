# %% [markdown]
# # AEM4L4 E12 — Integrador ADR chatbot financiero
#
# **Objetivo:** Combinar arquitectura, tokenizacion, LoRA, contexto y latencia en una decision completa.
#
# **Tipo:** Avanzado
#
# **Uso:** listo para Google Colab. Ejecuta las celdas en orden.

# %% [markdown]
# ## 1. Teoria breve
#
# El caso integrador exige balancear calidad, costo, latencia y adaptabilidad. El diseno correcto no es el mas sofisticado: es el que cumple restricciones reales.

# %% [markdown]
# ## 2. Grafico guia
#
# ```mermaid
# flowchart LR
#     User[Consulta financiera] --> R[Retriever de politicas relevantes]
#     R --> C[Contexto controlado]
#     C --> T[Tokenizer subword]
#     T --> M[Transformer moderado]
#     L[LoRA compliance] --> M
#     M --> V[Validacion y metricas]
#     V --> Answer[Respuesta bajo SLA]
# ```

# %% [markdown]
# ## 3. Ejemplo guiado
#
# La celda siguiente es intencionalmente pequena para poder explicarla en vivo antes de pasar a ejercicios combinados.

# %%
adr = {
    "arquitectura": "Transformer moderado",
    "tokenizer": "subword robusto para jerga financiera",
    "adaptacion": "LoRA compliance",
    "contexto": "retrieval + limite de tokens",
    "sla_ms": 600,
    "metricas": ["latencia_p95", "exactitud_regulatoria", "tokens_por_request"],
    "riesgos": ["jerga nueva", "contexto excesivo", "datos de adaptacion ruidosos"],
}

for clave, valor in adr.items():
    print(f"{clave}: {valor}")

# %% [markdown]
# ## 4. Interpretacion
#
# El ADR vuelve explicita la decision: modelo moderado, tokenizer robusto, LoRA y control de contexto para cumplir el SLA.

# %% [markdown]
# ## 5. Errores comunes
#
# - Elegir modelo grande sin medir latencia.
# - No planear actualizacion de terminologia regulatoria.
# - No registrar riesgos ni metricas.

# %% [markdown]
# ## 6. Mini practica
#
# Cambia el SLA a 2 segundos y explica que decisiones podrian cambiar.
