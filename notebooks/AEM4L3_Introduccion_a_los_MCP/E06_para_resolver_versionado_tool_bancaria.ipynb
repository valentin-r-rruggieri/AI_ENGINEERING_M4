# %% [markdown]
# # E06 - Para resolver: versionado de una tool bancaria
#
# ## Que vas a practicar
#
# Vas a versionar una tool sensible. El objetivo es aplicar la misma logica que usamos con `github_upsert_file`.

# %% [markdown]
# ## Caso
#
# Una tool bancaria actual:
#
# ```text
# transfer_money(from_account, to_account, amount, currency="USD")
# ```
#
# Cambios propuestos:
#
# | Cambio | Tu clasificacion |
# |---|---|
# | agregar `reference` opcional | ? |
# | renombrar `amount` a `value` | ? |
# | agregar `approval_id` obligatorio | ? |
# | agregar `receipt_url` al output | ? |

# %%
changes = {
    "agregar reference opcional": "pendiente",
    "renombrar amount a value": "pendiente",
    "agregar approval_id obligatorio": "pendiente",
    "agregar receipt_url al output": "pendiente",
}

for change, answer in changes.items():
    print(f"{change}: {answer}")

# %% [markdown]
# ## Para resolver
#
# Reemplaza `pendiente` por `aditivo` o `breaking`. Despues escribi una regla: cuando una tool mueve dinero, que confirmacion pedirias antes de ejecutar?
