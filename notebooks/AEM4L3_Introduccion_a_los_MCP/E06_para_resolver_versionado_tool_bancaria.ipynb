# %% [markdown]
# # E06 - Para resolver: versionar una tool de GitHub
#
# Objetivo: proponer evolucion compatible para `github_upsert_file`.

# %% [markdown]
# ## Grafico guia
#
# ```mermaid
# flowchart LR
#     A["Tool bancaria actual"] --> B["Nueva regulacion"]
#     B --> C["Evaluar contrato"]
#     C --> D["Versionar schema"]
#     D --> E["Plan de migracion"]
# ```

# %%
current_tool = {
    "name": "github_upsert_file",
    "input": ["owner", "repo", "path", "content", "commit_message", "branch"],
}
proposal = {
    "new_optional_fields": ["author_name", "author_email"],
    "new_required_fields": [],
    "renamed_fields": [],
}
current_tool, proposal

# %% [markdown]
# ## Pregunta
#
# Por que `author_name` opcional seria aditivo, pero renombrar `commit_message` seria breaking change?
