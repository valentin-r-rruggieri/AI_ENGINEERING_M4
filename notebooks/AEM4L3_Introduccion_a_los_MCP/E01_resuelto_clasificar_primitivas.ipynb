# %% [markdown]
# # E01 - Resuelto: clasificar primitivas MCP
#
# Objetivo: distinguir tool, resource y prompt con un caso GitHub.

# %% [markdown]
# ## Grafico guia
#
# ```mermaid
# flowchart TD
#     A["Capacidad MCP"] --> B{"Tipo"}
#     B --> C["Tool: accion"]
#     B --> D["Resource: contexto"]
#     B --> E["Prompt: instruccion reusable"]
# ```

# %%
items = {
    "github_create_repo": "tool",
    "github_upsert_file": "tool",
    "github://config": "resource",
    "repo_bootstrap_prompt": "prompt",
    "github_get_repo": "tool",
}
items

# %% [markdown]
# ## Lectura docente
#
# Una tool hace una accion o consulta operacional. Un resource entrega contexto controlado. Un prompt estandariza una instruccion reutilizable.

# %%
for name, primitive in items.items():
    print(f"{name}: {primitive}")
