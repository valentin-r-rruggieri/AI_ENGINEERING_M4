# %% [markdown]
# # E04 - Resuelto: elegir transporte
#
# Objetivo: justificar STDIO para Antigravity y VS Code.

# %% [markdown]
# ## Grafico guia
#
# ```mermaid
# flowchart TD
#     A["Caso de uso"] --> B{"Donde corre?"}
#     B -->|"local"| C["STDIO"]
#     B -->|"red/equipo"| D["HTTP"]
#     C --> E["Menos infraestructura"]
#     D --> F["Mas coordinacion"]
# ```

# %%
options = [
    {"transport": "STDIO", "recommended": True, "why": "cliente local arranca el server Python sin exponer puerto"},
    {"transport": "HTTP", "recommended": False, "why": "mejor para servicio remoto compartido"},
    {"transport": "SSE", "recommended": False, "why": "historico para streaming, menos directo para esta demo local"},
]
options

# %% [markdown]
# ## Donde se ve en Python
#
# `e01_github_mcp_server.py` termina con `mcp.run()`, compatible con clientes MCP locales por STDIO.
