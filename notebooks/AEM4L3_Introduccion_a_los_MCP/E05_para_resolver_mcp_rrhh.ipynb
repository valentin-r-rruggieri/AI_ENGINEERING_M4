# %% [markdown]
# # E05 - Para resolver: disenar un MCP de RRHH
#
# ## Que vas a practicar
#
# Vas a aplicar el patron del MCP GitHub a otro dominio: RRHH.

# %% [markdown]
# ## Guia
#
# Usa esta equivalencia:
#
# | MCP GitHub | MCP RRHH |
# |---|---|
# | crear repo | crear busqueda o candidato |
# | escribir README | guardar evaluacion |
# | `github://config` | `hr://policy` |
# | audit log | registro de decisiones |

# %% [markdown]
# ## Diagrama textual
#
# ```text
# MCP RRHH
#   tools     -> acciones sobre candidatos o busquedas
#   resources -> politicas y contexto controlado
#   prompts   -> guias para entrevistas y respuestas
# ```

# %%
mcp_rrhh = {
    "tools": [],
    "resources": [],
    "prompts": [],
}

# Completa estas listas con tus decisiones.
mcp_rrhh["tools"].append({"name": "candidate_get_profile", "side_effect": False})
mcp_rrhh["resources"].append({"uri": "hr://hiring-policy"})
mcp_rrhh["prompts"].append({"name": "candidate_interview_prompt"})

print(mcp_rrhh)

# %% [markdown]
# ## Para resolver
#
# Agrega:
#
# 1. Una tool con side effect.
# 2. Un resource de politicas.
# 3. Un prompt para entrevista.
# 4. Una regla de auditoria.
#
# Despues explica que parte seria equivalente a `github_upsert_file`.
