# %% [markdown]
# # E05 - Para resolver: disenar un MCP de repositorios internos
#
# Objetivo: practicar el diseno sin crear otro server Python.

# %% [markdown]
# ## Grafico guia
#
# ```mermaid
# flowchart LR
#     A["Caso RRHH"] --> B["Resource politicas"]
#     A --> C["Tool consulta candidatos"]
#     A --> D["Prompt entrevista"]
#     B --> E["Diseno MCP"]
#     C --> E
#     D --> E
# ```

# %%
exercise = {
    "scenario": "Una empresa quiere crear repos internos para proyectos de alumnos.",
    "task": "Definir 2 tools, 1 resource y 1 prompt usando el estilo del MCP GitHub.",
    "constraints": ["repos privados por defecto", "sin tool de borrado", "audit log obligatorio"],
}
exercise

# %%
student_answer_template = {
    "tools": [],
    "resources": [],
    "prompts": [],
    "security_notes": [],
}
student_answer_template

# %% [markdown]
# ## Pista docente
#
# La respuesta esperada deberia parecerse a `github_create_repo`, `github_upsert_file`, `github://config` y `repo_bootstrap_prompt`.
