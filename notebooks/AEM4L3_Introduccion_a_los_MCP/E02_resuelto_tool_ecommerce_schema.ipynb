# %% [markdown]
# # E02 - Resuelto: schema de una tool GitHub
#
# Objetivo: leer una tool MCP como contrato.

# %% [markdown]
# ## Grafico guia
#
# ```mermaid
# flowchart LR
#     A["Pedido e-commerce"] --> B["Input schema"]
#     B --> C["Validacion"]
#     C --> D["Tool de consulta"]
#     D --> E["Respuesta estructurada"]
# ```

# %%
github_create_repo_schema = {
    "name": "github_create_repo",
    "description": "Create a private GitHub repository",
    "input_schema": {
        "name": {"type": "string", "minLength": 3},
        "description": {"type": "string"},
        "private": {"type": "boolean", "default": True},
    },
    "output_schema": {
        "id": "integer",
        "full_name": "string",
        "owner": "string",
        "html_url": "string",
    },
}
github_create_repo_schema

# %% [markdown]
# ## Donde se ve en Python
#
# En `e01_github_mcp_server.py`, mirar `GitHubRepoResult` y la firma de `github_create_repo()`.
