# %% [markdown]
# # E07 - Inicial: tool, resource y prompt juntos
#
# ## Que vas a practicar
#
# Vas a disenar una mini capacidad MCP con las tres primitivas.

# %% [markdown]
# ## Referencia GitHub
#
# | Tipo | Capacidad real |
# |---|---|
# | Tool | `github_create_repo` |
# | Resource | `github://security-policy` |
# | Prompt | `safe_github_action_prompt` |
#
# Tu tarea es armar una combinacion similar para otro caso.

# %% [markdown]
# ## Diagrama textual
#
# ```text
# Tool     -> hace algo
# Resource -> informa algo
# Prompt   -> guia como pensar o redactar
# ```

# %%
mini_mcp = {
    "tool": {"name": "github_create_repo", "side_effect": True},
    "resource": {"uri": "github://security-policy", "side_effect": False},
    "prompt": {"name": "safe_github_action_prompt", "side_effect": False},
}

print(mini_mcp)
print("Regla:", "tool ejecuta; resource informa; prompt guia")

# %% [markdown]
# ## Para resolver
#
# Crea un `mini_mcp` para un sistema de soporte:
#
# - Tool para crear ticket.
# - Resource para leer politica de prioridad.
# - Prompt para redactar respuesta al cliente.
