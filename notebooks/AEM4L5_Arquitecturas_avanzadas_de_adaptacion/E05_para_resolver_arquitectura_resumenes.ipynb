# %% [markdown]
# # AEM4L5 E05 — Arquitectura para resúmenes
#
# **Objetivo:** practicar una decisión completa de adaptación y serving para un producto de resúmenes.
#
# **Tipo:** Para resolver.

# %% [markdown]
# ## Caso
#
# Una startup resume documentos bajo demanda. El tráfico es irregular, el presupuesto es bajo y varios clientes piden tono propio.
#
# ```mermaid
# flowchart LR
#     A["Documento"] --> B["Servicio de resumen"]
#     B --> C["Modelo base"]
#     C --> D{"Cliente / dominio"}
#     D --> E["Adapter LoRA cliente A"]
#     D --> F["Adapter LoRA cliente B"]
#     D --> G["Adapter LoRA cliente C"]
#     E --> H["Resumen"]
#     F --> H
#     G --> H
# ```

# %% [markdown]
# ## Consigna
#
# Completá una propuesta que incluya adaptación, serving, riesgos y métricas. Justificá cada decisión con una restricción del caso.

# %%
caso = {
    "producto": "resumen de documentos bajo demanda",
    "trafico": "irregular con picos",
    "presupuesto": "bajo",
    "personalizacion": "tono por cliente",
    "latencia_objetivo_ms": 2000,
}

propuesta = {
    "adaptacion": "TODO: LoRA/PEFT o full fine-tuning",
    "serving": "TODO: serverless, servidor persistente o híbrido",
    "profiling": "TODO: qué medir primero",
    "async": "TODO: dónde aplicarlo",
    "metricas": [],
    "riesgos": [],
}

propuesta

# %% [markdown]
# ## Pistas
#
# - Si hay muchos clientes y personalización moderada, pensá en adapters.
# - Si el tráfico es irregular y el modelo no exige estar siempre caliente, pensá en serverless.
# - Si la latencia viene de storage/API, pensá en async.
# - Si no sabés dónde se pierde tiempo, perfilá antes de optimizar.
