# %% [markdown]
# # PIM4 E06 — Adenda con múltiples cambios
#
# **Objetivo:** Identificar territorio, pago y terminación.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Caso con más de una modificación.

# %%
original = "El proveedor prestará servicios en Argentina. El pago será mensual. El contrato podrá terminarse con aviso de 30 días."
amendment = "El proveedor prestará servicios en Argentina y Uruguay. El pago será quincenal. El contrato podrá terminarse con aviso de 15 días."

# TODO: identificar sections_changed, topics_touched y summary_of_the_change
