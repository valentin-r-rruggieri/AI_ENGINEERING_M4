# %% [markdown]
# # PIM4 E03 — ExtractionAgent
#
# **Objetivo:** Extraer cambios usando el mapa contextual.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Devuelve JSON listo para validación.

# %%
def extraction_agent(original_text, amendment_text, context_map):
    return {
        "sections_changed": ["payment_terms"],
        "topics_touched": ["monto mensual", "condiciones comerciales"],
        "summary_of_the_change": "Se modifica el monto mensual del servicio."
    }

result = extraction_agent("pago $1000", "pago $1200", "mapa contextual")
result
