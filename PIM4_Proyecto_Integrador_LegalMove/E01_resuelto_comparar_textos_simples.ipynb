# %% [markdown]
# # PIM4 E01 — Comparar textos simples
#
# **Objetivo:** Detectar cambio mínimo entre contrato y adenda.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Primer paso antes de visión y agentes.

# %%
original = "El pago mensual será de $1000."
amendment = "El pago mensual será de $1200."

output = {
    "sections_changed": ["payment_terms"],
    "topics_touched": ["monto mensual"],
    "summary_of_the_change": "El monto mensual aumentó de $1000 a $1200."
}
output
