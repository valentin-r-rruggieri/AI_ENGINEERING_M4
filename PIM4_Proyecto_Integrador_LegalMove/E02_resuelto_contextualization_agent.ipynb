# %% [markdown]
# # PIM4 E02 — ContextualizationAgent
#
# **Objetivo:** Separar contexto de extracción.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Este agente no debe extraer cambios finales.

# %%
def contextualization_agent(original_text, amendment_text):
    return "Contrato con secciones de pago, duración y terminación. La adenda parece modificar condiciones de pago. No extraer cambios finales."

print(contextualization_agent("contrato original", "adenda"))
