# %% [markdown]
# # PIM4 E05 — Contrato de alquiler
#
# **Objetivo:** Resolver comparación de duración contractual.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Basado en E01 y E03.

# %%
original = "El contrato tendrá una duración de 12 meses."
amendment = "El contrato tendrá una duración de 18 meses."

# TODO: devolver ContractChangeOutput válido
output = {
    "sections_changed": [],
    "topics_touched": [],
    "summary_of_the_change": ""
}
output
