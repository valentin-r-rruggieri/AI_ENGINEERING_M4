# %% [markdown]
# # AEM4L4 E06 — Tokenización legal
#
# **Objetivo:** Simular tokenización en dominio legal.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Comparar word-level, character-level, BPE y WordPiece.

# %%
words = ["contraprestación", "usufructuario", "responsabilidadcontractual", "microjurisprudencia"]

# TODO: completar posibles tokenizaciones
for w in words:
    print(w)
