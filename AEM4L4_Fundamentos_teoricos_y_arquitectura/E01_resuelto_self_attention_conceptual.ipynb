# %% [markdown]
# # AEM4L4 E01 — Self-attention conceptual
#
# **Objetivo:** Entender attention sin matemática pesada.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# La palabra bloqueó debe mirar sujeto, objeto, contradicción y causa.

# %%
sentence = "Aunque el cliente pagó la factura, el sistema bloqueó su cuenta por error."
attention_map = {
    "bloqueó": ["sistema", "cuenta", "pagó", "factura", "error"]
}

print(sentence)
print("Tokens relevantes para 'bloqueó':", attention_map["bloqueó"])
