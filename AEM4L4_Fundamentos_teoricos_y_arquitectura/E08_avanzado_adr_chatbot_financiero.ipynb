# %% [markdown]
# # AEM4L4 E08 — Avanzado | ADR chatbot financiero
#
# **Objetivo:** Tomar decisiones de arquitectura.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Completar modelo, tokenizer, adaptación, riesgos y métricas.

# %%
adr = {
    "modelo": "TODO",
    "tokenizer": "TODO",
    "adaptacion": "TODO",
    "riesgos": [],
    "metricas": []
}

adr
