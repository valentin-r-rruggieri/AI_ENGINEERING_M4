# %% [markdown]
# # AEM4L4 E03 — Costo cuadrático de atención
#
# **Objetivo:** Calcular tokens × tokens.
#
# **Tipo:** Resuelto
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Duplicar tokens cuadruplica aproximadamente relaciones de atención.

# %%
for tokens in [10, 25, 50, 100]:
    print(tokens, "tokens →", tokens * tokens, "relaciones de atención")
