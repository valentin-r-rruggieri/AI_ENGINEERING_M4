# %% [markdown]
# # AEM4L4 E05 — Attention caso médico
#
# **Objetivo:** Analizar atención en una oración médica.
#
# **Tipo:** Para resolver / práctica
#
# **Uso:** listo para Google Colab. Ejecutá las celdas en orden.

# %% [markdown]
# Completar tokens relevantes para médico, pidió y dolor.

# %%
sentence = "Aunque el paciente no tenía fiebre, el médico pidió estudios por el dolor persistente."

# TODO: completar
attention = {
    "médico": [],
    "pidió": [],
    "dolor": []
}

attention
